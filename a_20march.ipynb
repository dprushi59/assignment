# %% [raw]
# #1
# Data encoding is the process of converting data from one format or representation into another format, typically for the purpose of storage, transmission, or processing. In the context of data science, data encoding is crucial for handling various types of data, ensuring compatibility between different systems, and optimizing the use of resources.
#
# There are several reasons why data encoding is important in data science:
#
# 1. **Normalization**: Data encoding can be used to normalize data, which means transforming data into a standard format or range. This is essential for ensuring that data from different sources can be compared or combined effectively. For example, converting numerical values to a common scale (like scaling all values between 0 and 1) helps prevent certain variables from having a disproportionate influence on the analysis.
#
# 2. **Categorical Data Handling**: Categorical data, which includes labels or categories, needs to be encoded into numerical form for many machine learning algorithms to work effectively. Various encoding techniques like one-hot encoding, label encoding, and ordinal encoding are used to represent categorical data in a format that algorithms can understand.
#
# 3. **Text and Natural Language Processing (NLP)**: In NLP tasks, text data needs to be converted into numerical vectors for machine learning algorithms to process. Techniques like tokenization, word embedding, and bag-of-words encoding are used to represent textual data in a way that captures its semantic meaning and relationships.
#
# 4. **Efficient Storage and Transmission**: Data encoding can compress data to reduce storage space and speed up data transmission. Encoding schemes like Huffman coding or delta encoding can significantly reduce the amount of space required to store or transmit data, which is crucial for managing large datasets and real-time applications.
#
# 5. **Data Privacy and Security**: Data encoding can also play a role in protecting sensitive information. Techniques like encryption encode data to make it unreadable without the appropriate decryption key, ensuring data privacy and security.
#
# 6. **Feature Engineering**: Feature engineering involves creating new features (variables) from existing ones to improve the performance of machine learning models. Data encoding can be used to create meaningful features from raw data, such as deriving date-related features (day of the week, month, year) from a date column.
#
# 7. **Sparse Data**: For datasets with a lot of missing or sparse data, encoding techniques can help manage these gaps and ensure that machine learning algorithms can still process the data effectively.
#
# Overall, data encoding is a fundamental aspect of data preprocessing and manipulation in data science. It enables data scientists and machine learning practitioners to work with diverse types of data and transform them into formats that can be easily analyzed and utilized by various algorithms and models.

# %% [raw]
# #2
# Nominal encoding, also known as label encoding, is a data encoding technique used to convert categorical variables into numerical values. In nominal encoding, each unique category or label is assigned a unique integer code. However, it's important to note that the numerical values assigned in nominal encoding have no inherent order or hierarchy; they are simply used as identifiers for different categories.
#
# Here's an example of nominal encoding and how it could be used in a real-world scenario:
#
# **Scenario: Customer Segmentation**
#
# Imagine you work for an e-commerce company that wants to segment its customers based on their shopping preferences. One of the features you have is the "Product Category" that represents the category of products a customer typically buys. The categories include "Electronics," "Clothing," "Books," and "Home Decor."
#
# To perform customer segmentation using machine learning algorithms, you need to convert the "Product Category" feature into numerical values. You decide to use nominal encoding:
#
# Original Data:
# ```
# | Customer ID | Product Category |
# |-------------|------------------|
# | 1           | Electronics     |
# | 2           | Clothing        |
# | 3           | Books           |
# | 4           | Home Decor      |
# | 5           | Electronics     |
# ```
#
# After Nominal Encoding:
# ```
# | Customer ID | Encoded Category |
# |-------------|------------------|
# | 1           | 0                |
# | 2           | 1                |
# | 3           | 2                |
# | 4           | 3                |
# | 5           | 0                |
# ```
#
# In this example, each unique product category is assigned a numerical code. The encoded values have no inherent order; they simply represent different categories. These encoded values can then be used as input features for machine learning algorithms. However, it's important to mention that some machine learning algorithms might mistakenly interpret the encoded values as having an ordinal relationship (meaning one is greater than another), which could lead to incorrect results. In cases where there is no meaningful ordinal relationship among categories, other encoding techniques like one-hot encoding or binary encoding might be more suitable.

# %% [raw]
# #3
# Nominal encoding is preferred over one-hot encoding in situations where there is a large number of unique categories or labels within a categorical variable. One-hot encoding can lead to the creation of a large number of binary columns, resulting in a high-dimensional dataset, increased memory usage, and potentially slow processing times. In such cases, nominal encoding can be a more efficient alternative, as it represents categories using a single numerical column.
#
# Here's a practical example to illustrate when nominal encoding might be preferred:
#
# Scenario: Customer Reviews
#
# Suppose you're working on a sentiment analysis project where you're analyzing customer reviews for a wide range of products. One of the features in your dataset is "Product Type," which indicates the specific type of product that each review pertains to. The "Product Type" can have numerous unique values, such as "Electronics," "Clothing," "Books," "Home Decor," "Kitchen Appliances," "Toys," and so on.
#
# If you were to use one-hot encoding for the "Product Type" feature, you'd create a binary column for each unique product type. With a large number of unique product types, this would lead to an excessive number of binary columns, making your dataset very wide and potentially causing performance and memory issues.
#
# Instead, using nominal encoding in this situation could be more practical. You'd assign a unique numerical code to each product type. This approach reduces the dimensionality of the dataset while still preserving the information about the different product types.
#
# Original Data:
# ```
# | Review ID | Product Type    |
# |-----------|-----------------|
# | 1         | Electronics    |
# | 2         | Clothing       |
# | 3         | Books          |
# | 4         | Home Decor     |
# | 5         | Electronics    |
# | ...       | ...            |
# ```
#
# After Nominal Encoding:
# ```
# | Review ID | Encoded Type |
# |-----------|--------------|
# | 1         | 0            |
# | 2         | 1            |
# | 3         | 2            |
# | 4         | 3            |
# | 5         | 0            |
# | ...       | ...          |
# ```
#
# In this example, nominal encoding reduces the categorical feature "Product Type" into a single column of numerical codes. This approach is more efficient compared to creating numerous binary columns through one-hot encoding.
#
# However, it's essential to be cautious when using nominal encoding. If there is any inherent order or hierarchy among the categories, nominal encoding may not be appropriate, and other encoding techniques like one-hot encoding or ordinal encoding should be considered instead.

# %% [raw]
# #4
# i have a dataset contains categorical data with 5 unique values,so it doesn't have any inherent order then we can apply nominal or one hot encoding but values are unique so nominal encoding should be preffered and transform data.We cannot preffered one hot encoding cause it increases dimensionality of dataset so nominal encoding should be preffered.

# %% [raw]
# #5
# if we use nominal encoding 2 columns is enough (as same as no. of categorical columns) but if we use one hot encoding then we have to check how many unique categories present in a categorical column let's say we have 'm' unique categories in column 1 and 'n' unique categories in column 2 then by applying onehotencoding m+n new binary columns will be created

# %% [raw]
# #6
# For encoding categorical data in a dataset about different types of animals, including their species, habitat, and diet, the appropriate encoding technique would typically depend on the nature of the categorical variables and the machine learning algorithm you plan to use. Two common encoding techniques are **One-Hot Encoding** and Label Encoding. Let's discuss both and their justifications:
#
# 1. One-Hot Encoding (Nominal Encoding):
#    One-hot encoding creates binary columns for each unique category in a categorical variable. Each binary column represents the presence or absence of a specific category. This technique is suitable when there is no inherent ordinal relationship between the categories and when the categories are not inherently comparable.
#
#    Justification:
#    - Species: If the "species" feature contains non-hierarchical categorical values like "lion," "elephant," and "giraffe," using one-hot encoding would be suitable. Species categories do not have any inherent order or numerical meaning, making one-hot encoding the appropriate choice.
#    - Habitat: If the "habitat" feature includes categories like "forest," "desert," and "ocean," one-hot encoding is again suitable. Habitats are distinct categories without any inherent order.
#    - Diet: If the "diet" feature consists of categories such as "carnivore," "herbivore," and "omnivore," one-hot encoding is appropriate. Diet types are mutually exclusive categories.
#
# 2. Label Encoding:
#    Label encoding assigns a unique integer label to each category in a categorical variable. This technique is suitable when there is a clear ordinal relationship among the categories, and this order can be meaningful to the algorithm.
#
#    Justification:
#    - If any of the categorical variables have an inherent order that can impact the model's performance, you might consider using label encoding. For example, if the "diet" categories have a natural ordering such as "herbivore" < "omnivore" < "carnivore," then label encoding could capture this ordinal relationship.
#
# In most cases, considering the nature of the categorical variables in your animal dataset (species, habitat, and diet), one-hot encoding is likely the better choice. It ensures that the machine learning algorithm treats each category as a separate and distinct entity, preventing any unintended ordinal relationships from influencing the model.

# %%
#7
# i have 5 features (customer gender,age,tenure,monthly charges,contract type)
#1.Label Encoding - encoded on the basis of alphabetical order
import pandas as pd 
gender = ["Male", "Female", "Male", "Female", "Male", "Female", "Male", "Male", "Female", "Female"]
age = [32, 45, 22, 60, 28, 50, 40, 19, 65, 35]
tenure = [12, 24, 6, 48, 3, 36, 18, 1, 60, 9]
monthly_charges = [50, 80, 30, 70, 45, 60, 55, 40, 85, 48]
contract_type = ["One year", "Two year", "Month-to-month", "Two year", "Month-to-month", "One year", "Month-to-month", "Month-to-month", "Two year", "One year"]

data = {
    "gender": gender,
    "age": age,
    "tenure": tenure,
    "monthly_charges": monthly_charges,
    "contract_type": contract_type
}

df = pd.DataFrame(data)
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
encoded = encoder.fit_transform(df[['contract_type']])
l = list(encoded)
df['contract_type_labeled'] = l
df
# Out:
# /opt/conda/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#    gender  age  tenure  monthly_charges   contract_type  contract_type_labeled
# 0    Male   32      12               50        One year                      1
# 1  Female   45      24               80        Two year                      2
# 2    Male   22       6               30  Month-to-month                      0
# 3  Female   60      48               70        Two year                      2
# 4    Male   28       3               45  Month-to-month                      0
# 5  Female   50      36               60        One year                      1
# 6    Male   40      18               55  Month-to-month                      0
# 7    Male   19       1               40  Month-to-month                      0
# ...

# %%
#Now using onehotencoding
from sklearn.preprocessing import OneHotEncoder
encoder = OneHotEncoder()
encoded = encoder.fit_transform(df[['gender','contract_type']])
encoded_df = pd.DataFrame(encoded.toarray(),columns=encoder.get_feature_names_out())
pd.concat([df,encoded_df],axis=1)
# Out:
#    gender  age  tenure  monthly_charges   contract_type  \
# 0    Male   32      12               50        One year
# 1  Female   45      24               80        Two year
# 2    Male   22       6               30  Month-to-month
# 3  Female   60      48               70        Two year
# 4    Male   28       3               45  Month-to-month
# 5  Female   50      36               60        One year
# 6    Male   40      18               55  Month-to-month
# 7    Male   19       1               40  Month-to-month
# 8  Female   65      60               85        Two year
# 9  Female   35       9               48        One year
#
#    contract_type_labeled  gender_Female  gender_Male  \
# 0                      1            0.0          1.0
# 1                      2            1.0          0.0
# 2                      0            0.0          1.0
# 3                      2            1.0          0.0
# 4                      0            0.0          1.0
# ...
